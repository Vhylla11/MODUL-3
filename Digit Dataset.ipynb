# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.datasets import load_digits

# %%
digit = load_digits()
dir (digit)
# Out:
# ['DESCR', 'data', 'images', 'target', 'target_names']

# %%
# digit ['data']
digit ['data'].shape ## untuk liat berapa jumlah data
# digit ['image'].shape
# Out:
# (1797, 64)

# %%
import matplotlib.pyplot as plt

i = 2
plt.imshow (digit ['images'][i],cmap='gray')
plt.title (f'ini  {digit["target"][i]}')
# Out:
# Text(0.5, 1.0, 'ini  2')

# %% [markdown]
# ### Kalau mau tampilkan 10 data pertama

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (14,8))

for i in range (10) :
    plt.subplot(2,5,i+1)  ## 2 : 2 baris, 5 : 1 baris isinya da 5 , 
    plt.imshow (digit ['images'][i],cmap='gray')
    plt.title (f'ini  {digit["target"][i]}')
